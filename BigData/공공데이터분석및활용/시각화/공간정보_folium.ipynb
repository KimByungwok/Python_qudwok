# %%
import pandas as pd
import json

# %%
# Folium 라이브러리 
#   - 지도 위에 데이터 시각화
#    - 웹기반 지도 출력
#   - 라이브러리 설치 : pip install folium

# %%
# 라이브러리 불러오기
import folium

# %%
# 1. 지도 만들기
#  - Map()함수 사용, zoom 및 scroll 가능
#  - location=[위도,경도]
#  - zoom_start : 1(축소)~15(확대)

서울지도 = folium.Map(location=[37.55,126.98], zoom_start=12)

# %%
서울지도.save('./서울.html')

# %%
# extension->open in webbrowser 검색 후 설치
# alt + b로 실행

# %%
# 2. 지도 스타일 적용
#    - tiles : 타일의 종류, Stamen Terrain(산악지형 강조), Stamen Toner(흑백 도로망 강조), Stamen Watercolor(수채화 형식 표현)
#    - http://maps.stamen.com 참조
서울지도2 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain',zoom_start=12)
서울지도3 = folium.Map(location=[37.55,126.98], tiles='Stamen Toner', zoom_start=15)
서울지도4 = folium.Map(location=[37.55,126.98], tiles='Stamen Watercolor', zoom_start=10)

서울지도2.save('./seoul2.html')
서울지도3.save('./seoul3.html')
서울지도4.save('./seoul4.html')

# %%
# 지도 출력해보기
# Jupyter Notebook에서는 바로 출력 가능
# 일반적으로 save() 메소드로 html 형식으로 저장 후 활용

서울지도2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab2918c6009938f3be47aec3da4be4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab2918c6009938f3be47aec3da4be4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6dab2918c6009938f3be47aec3da4be4 = L.map(
#                 &quot;map_6dab2918c6009938f3be47aec3da4be4&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37087febbf5b4f1a61c6f147cfa40ec7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dab2918c6009938f3be47aec3da4be4);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 3. 지도에 마커 표시하기(일반적인 마커 이미지 사용)

df = pd.read_excel('./서울지역 대학교 위치.xlsx')
대학교 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain',zoom_start=12)

for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat, lng], popup=  name).add_to(대학교)

대학교.save('./서울지역 대학교 위치.html')

# %%
# 마커 표시된 지도 출력
대학교
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaf12afe184e61681046e1c8366cda30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaf12afe184e61681046e1c8366cda30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_aaf12afe184e61681046e1c8366cda30 = L.map(
#                 &quot;map_aaf12afe184e61681046e1c8366cda30&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82a356f7623f522e1377e058e8f48962 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#             var marker_afa60ef2af0912629d1a94ffc4000a54 = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_bda2ccdb9ff5b2f39e6afafeb0aac880 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_47fcafaa3c2d38c78d00bcc14fea331a = $(`&lt;div id=&quot;html_47fcafaa3c2d38c78d00bcc14fea331a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_bda2ccdb9ff5b2f39e6afafeb0aac880.setContent(html_47fcafaa3c2d38c78d00bcc14fea331a);
#
#
#         marker_afa60ef2af0912629d1a94ffc4000a54.bindPopup(popup_bda2ccdb9ff5b2f39e6afafeb0aac880)
#         ;
#
#
#
#
#             var marker_61353a4fe0c0ad54a8e684554a93fb05 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_c8b034cb2f61fb6def1912e6f613cdfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_df3d99736d423b8ddf764a6b173bfa65 = $(`&lt;div id=&quot;html_df3d99736d423b8ddf764a6b173bfa65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_c8b034cb2f61fb6def1912e6f613cdfe.setContent(html_df3d99736d423b8ddf764a6b173bfa65);
#
#
#         marker_61353a4fe0c0ad54a8e684554a93fb05.bindPopup(popup_c8b034cb2f61fb6def1912e6f613cdfe)
#         ;
#
#
#
#
#             var marker_422b9f626883c5edfa9435f8a8ea9a61 = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_d13823e599be4b62aad90ec05ccd5584 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fe50b8859c411a494cf2bbf3439961fb = $(`&lt;div id=&quot;html_fe50b8859c411a494cf2bbf3439961fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_d13823e599be4b62aad90ec05ccd5584.setContent(html_fe50b8859c411a494cf2bbf3439961fb);
#
#
#         marker_422b9f626883c5edfa9435f8a8ea9a61.bindPopup(popup_d13823e599be4b62aad90ec05ccd5584)
#         ;
#
#
#
#
#             var marker_db6f187b7aedb8e6f482a27b1ffbe0a6 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_61190d9aa2e2fcff70d27408c1d60e7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_308cfde7446609ac5fa77d50937dd09f = $(`&lt;div id=&quot;html_308cfde7446609ac5fa77d50937dd09f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#             popup_61190d9aa2e2fcff70d27408c1d60e7a.setContent(html_308cfde7446609ac5fa77d50937dd09f);
#
#
#         marker_db6f187b7aedb8e6f482a27b1ffbe0a6.bindPopup(popup_61190d9aa2e2fcff70d27408c1d60e7a)
#         ;
#
#
#
#
#             var marker_3be63f08513724d472b7bf8ade75e763 = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_7fbee0c10326519fc36a774bc75f20a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_aa1897274a403647f0b5e72aef7030d5 = $(`&lt;div id=&quot;html_aa1897274a403647f0b5e72aef7030d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#             popup_7fbee0c10326519fc36a774bc75f20a3.setContent(html_aa1897274a403647f0b5e72aef7030d5);
#
#
#         marker_3be63f08513724d472b7bf8ade75e763.bindPopup(popup_7fbee0c10326519fc36a774bc75f20a3)
#         ;
#
#
#
#
#             var marker_c310c1489ceec18c23a8c4f8610cd056 = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}
#             ).addTo(map_aaf12afe184e61681046e1c8366cda30);
#
#
#         var popup_1fbc5d7f88b73f68998102e87cf48f4c = L.popup(

# %%
# 지도에 원형 마커 표시해보기

df = pd.read_excel('./서울지역 대학교 위치.xlsx')
대학교 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain',zoom_start=12)

for name, lat, lng in zip(df.index, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
    radius = 10,
    color='brown',
    fill=True,
    fil_color='coral',
    fill_opacity=0.7,
    popup=name
    ).add_to(대학교)

대학교.save('./서울지역 대학교 위치_원형마커.html')

# %%
# 데이터 프레임 출력
df

# %%
# 원형마커 지도 출력해보기
대학교
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49310b12fb085a8deeb72b44f7719e11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49310b12fb085a8deeb72b44f7719e11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_49310b12fb085a8deeb72b44f7719e11 = L.map(
#                 &quot;map_49310b12fb085a8deeb72b44f7719e11&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b9cc3b1e1fa8f2076c1a1c6c8cfc9b2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49310b12fb085a8deeb72b44f7719e11);
#
#
#             var circle_marker_d2bb66ad78bbbf250c92032954892a61 = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49310b12fb085a8deeb72b44f7719e11);
#
#
#         var popup_fc23f1b13652d5ea46b5d3072f3121e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_34bb8ca2bf5ab77bc361d7e41b80d4ef = $(`&lt;div id=&quot;html_34bb8ca2bf5ab77bc361d7e41b80d4ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#             popup_fc23f1b13652d5ea46b5d3072f3121e4.setContent(html_34bb8ca2bf5ab77bc361d7e41b80d4ef);
#
#
#         circle_marker_d2bb66ad78bbbf250c92032954892a61.bindPopup(popup_fc23f1b13652d5ea46b5d3072f3121e4)
#         ;
#
#
#
#
#             circle_marker_d2bb66ad78bbbf250c92032954892a61.bindTooltip(
#                 `&lt;div&gt;
#                      눌러봐!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_de9cc4cd12c6323637f78eb7a8b358c2 = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49310b12fb085a8deeb72b44f7719e11);
#
#
#         var popup_d5139e1d6abe867ebf131375e0aa039a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fa3e55fdf829c8d94af15f6d37cb083f = $(`&lt;div id=&quot;html_fa3e55fdf829c8d94af15f6d37cb083f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_d5139e1d6abe867ebf131375e0aa039a.setContent(html_fa3e55fdf829c8d94af15f6d37cb083f);
#
#
#         circle_marker_de9cc4cd12c6323637f78eb7a8b358c2.bindPopup(popup_d5139e1d6abe867ebf131375e0aa039a)
#         ;
#
#
#
#
#             circle_marker_de9cc4cd12c6323637f78eb7a8b358c2.bindTooltip(
#                 `&lt;div&gt;
#                      눌러봐!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d2c4076556bbf8cd7ada84091a5dcd08 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_49310b12fb085a8deeb72b44f7719e11);
#
#
#         var popup_330a81bd7339199e863f29d789f4ed84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_36cbc6c8e0cf8f1dcd3dd4f2e1cc9110 = $(`&lt;div id=&quot;html_36cbc6c8e0cf8f1dcd3dd4f2e1cc9110&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#             popup_330a81bd7339199e863f29d789f4ed84.setContent(html_36cbc6c8e0cf8f1dcd3dd4f2e1cc9110);
#
#
#         circle

# %%
# 마커 누르면 대학교 이름 나오게 해보기
# 한글문제 처리

df = pd.read_excel('./서울지역 대학교 위치.xlsx')
대학교 = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain',zoom_start=12)
tooltip = 'Click me!'
for name, lat, lng in zip(df.name, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
    radius = 10,
    color='brown',
    fill=True,
    fil_color='coral',
    fill_opacity=0.7,
    popup=name,
    tooltip = tooltip
    ).add_to(대학교)

대학교.save('./서울지역 대학교 위치_원형마커(툴팁).html')

# %%
대학교
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00b96d4e5cdb78acc974e60e59299f65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00b96d4e5cdb78acc974e60e59299f65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_00b96d4e5cdb78acc974e60e59299f65 = L.map(
#                 &quot;map_00b96d4e5cdb78acc974e60e59299f65&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cb86dd70bb8ab9cb55557da6fcf0070 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00b96d4e5cdb78acc974e60e59299f65);
#
#
#             var circle_marker_011c3a457361b386d3660ce244bea8fb = L.circleMarker(
#                 [37.592573, 127.046737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00b96d4e5cdb78acc974e60e59299f65);
#
#
#         var popup_4f6a4fc079d1a5ce35bef2c722d0db08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_de94388ecd67fef0e21f3e1ae936e5cf = $(`&lt;div id=&quot;html_de94388ecd67fef0e21f3e1ae936e5cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#             popup_4f6a4fc079d1a5ce35bef2c722d0db08.setContent(html_de94388ecd67fef0e21f3e1ae936e5cf);
#
#
#         circle_marker_011c3a457361b386d3660ce244bea8fb.bindPopup(popup_4f6a4fc079d1a5ce35bef2c722d0db08)
#         ;
#
#
#
#
#             circle_marker_011c3a457361b386d3660ce244bea8fb.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_69a4c08eb5a29731ed9684df3a7d971f = L.circleMarker(
#                 [37.5483449, 126.8547974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00b96d4e5cdb78acc974e60e59299f65);
#
#
#         var popup_56571c55e6b8eed72f7ed0e805f17d55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_39850a79b11bd388ae8cca9e9b89e4db = $(`&lt;div id=&quot;html_39850a79b11bd388ae8cca9e9b89e4db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#             popup_56571c55e6b8eed72f7ed0e805f17d55.setContent(html_39850a79b11bd388ae8cca9e9b89e4db);
#
#
#         circle_marker_69a4c08eb5a29731ed9684df3a7d971f.bindPopup(popup_56571c55e6b8eed72f7ed0e805f17d55)
#         ;
#
#
#
#
#             circle_marker_69a4c08eb5a29731ed9684df3a7d971f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_7d63cc610b1832b2735997ad80486953 = L.circleMarker(
#                 [37.5859218, 127.0043275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;brown&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_00b96d4e5cdb78acc974e60e59299f65);
#
#
#         var popup_5ca2afe37f1c656ab445bc7be7643173 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bad45aa5ade7eec1a9a48afdf6053124 = $(`&lt;div id=&quot;html_bad45aa5ade7eec1a9a48afdf6053124&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#             popup_5ca2afe37f1c656ab445bc7be7643173.setContent(html_bad45aa5ade7eec1a9a48af

# %%
# 
# GeoJSON(지오제이슨) : 
#   - 위치정보를 갖는 점을 기반으로 체계적으로 지형을 표현하기 위해 설계된 개방형 공개 표준 형식
#   -  JSON인 자바스그립트 오브젝트 노테이션(Object Notation)을 사용
#   -  [경도, 위도] 표기법 사용, cf.구글맵이나 오픈스트리트맵서비스는 [위도,경도] 표기법 사용
#       https://ko.wikipedia.org/wiki/GeoJSON 참조
#

# %%
# 5. 지도영역에 단계구분도(Choropleth - Map)
file_path = './경기도인구데이터.xlsx'
df = pd.read_excel(file_path, index_col='구분')
df.columns = df.columns.map(str)

# 경기도 시군구 경계 정보를 가진 geo-json 파일 불러오기
geo_path = './경기도행정구역경계.json'
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))

# 경기도 지도 만들기
g_map = folium.Map(location=[37.5502,126.982], 
                   tiles='Stamen Terrain', zoom_start=9)

# 출력할 연도 선택 (2007 ~ 2017년 중에서 선택)
# 직접 입력 받도록 변경 해보기
year = '2007'  

# Choropleth(일종의 주제별 thematic) 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=geo_data,    # 지도 경계
                 data = df[year],      # 표시하려는 데이터
                 columns = [df.index, df[year]],  # 열 지정
                 fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
                 threshold_scale=[10000, 100000, 300000, 500000, 700000],               
                 key_on='feature.properties.name',
                 ).add_to(g_map)

# 지도를 HTML 파일로 저장하기
g_map.save('./gyonggi_population_' + year + '.html')

# %%
# 경기 지도 출력해 보기
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d007c7f953ee5b3192185efa8f2c1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d007c7f953ee5b3192185efa8f2c1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f0d007c7f953ee5b3192185efa8f2c1d = L.map(
#                 &quot;map_f0d007c7f953ee5b3192185efa8f2c1d&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c005e7bebb7232cae50d8d65ced48afc = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0d007c7f953ee5b3192185efa8f2c1d);
#
#
#             var choropleth_2e69b40fb86265d2d6acbe9bdbb02fdd = L.featureGroup(
#                 {}
#             ).addTo(map_f0d007c7f953ee5b3192185efa8f2c1d);
#
#
#         function geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_styler(feature) {
#             switch(feature.properties.code) {
#                 case 31380: case 31370: case 31350: case 31110: case 31080:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case 31240: case 31200: case 31192: case 31150: case 31130: case 31101: case 31092: case 31091: case 31070: case 31060: case 31051: case 31042: case 31030: case 31023: case 31012:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ed40dc45dbb26c79029f8c4f4c1a114d = L.geoJson(null, {
#                 onEachFeature: geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_onEachFeature,
#
#                 style: geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_styler,
#         });
#
#         function geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_add (data) {
#             geo_json_ed40dc45dbb26c79029f8c4f4c1a114d
#                 .addData(data)
#                 .addTo(choropleth_2e69b40fb86265d2d6acbe9bdbb02fdd);
#         }
#             geo_json_ed40dc45dbb26c79029f8c4f4c1a114d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.56113535909492, 37.6256560539258], [127.57290963929243, 37.61087369350498], [127.56366973908277, 37.5842624297699], [127.52226606559191, 37.5828628697518], [127.50048767007603, 37.569036373178626], [127.47687473909174, 37.574448241913856], [127.47565866803647, 37.60512112601634], [127.44699730711024, 37.64497584741164], [127.4272349102434, 37.66284420898682], [127.40156700708162, 37.64806970784708], [127.3732642199939, 37.6453987554284], [127.3542931884407, 37.6250006376975], [127.34360057873045, 37.588997440929354], [127.31002843450217, 37.53523876142835], [127.30923294884336, 37.5135706079458], [127.32809611134748, 37.53133849534739], [127.3663244453597, 37.52716845880826], [127.38286320755414, 37.50147517965334], [127.39046783039153, 37.47413422098595], [127.37490698722792, 37.455072688441305], [127.39174400683049, 37.4256483411369], [127.40276739880215, 37.41856433413549], [127.4250053080982, 37.43669952587185], [127.4817900304572, 37.42084413829662], [127.51015267026155, 37.43699555518635], [127.52501209957308, 37.43192043868044], [127.53910572062166, 37.40849283821634], [127.60528700481163, 37.416969769508924], [127.63754040237271, 37.41065607591271], [127.6491838950862, 37.402042953108506], [127.66976823475012, 37.40884431255766], [127.71071536074867, 37.40736583858037], [127.70347417929173, 37.371054026073324], [127.76165381178268, 37.36421926003675], [127.77952402154285, 37.368441789396854], [127.80397287036232, 37.432516049235865], [127.79833492163134, 37.460500237870505], [127.77664798308412, 37.48883635932707], [127.77611527652192, 37.50328615763377], [127.80855972024105, 37.53220450961153], [127.8445769305193, 37.53621789699497], [127.85162286006927, 37.55037340096326], [127.81507964099751, 37.5618389022189], [127.79492564827493, 37.58252978378627], [127.76838776707211, 37.580178216134605], [127.75614914198108, 37.589477424718204], [127.7102810556826, 37.58360128682645], [127.6986938386
