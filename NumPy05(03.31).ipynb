# %% [markdown]
# # csv 등 파일 읽기 저장하기

# %%
import pandas as pd

filepath = "sample\csv_sample.csv"

df = pd.read_csv(filepath,index_col=None)
df

# %%
import pandas as pd

filepath = "sample\남북한발전전력량.xlsx"

df = pd.read_excel(filepath,header=None)    #header = 0 이 default 옵션임
df

# %%
import pandas as pd

df = pd.read_json("sample/json_sample.json")
print(df.columns)
print(df.index)

df

# %%
# pip install lxml 이거 설치하기

import pandas as pd

filepath = "sample\sample.html"
tables = pd.read_html(filepath)
print(len(tables))
print()

for index in range(len(tables)):
    print("tables[%s]" % index)
    print(tables[index])
    print()
    

df = tables[1]

df.set_index(['name'],inplace = True)
df

# %%
import pandas as pd
import requests # http 요청 패키지 로드 pip install requests
import re       # 정규표현식 패키지 로드 pip install regex
from bs4 import BeautifulSoup # 웹스크래핑 패키지 로드 pip install beautifulsoup4


etf_url = "https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
response = requests.get(etf_url)
soup_result=BeautifulSoup(response.text, 'lxml')
selected_rows=soup_result.select('dev > ul > li')

print(response.text)

print(selected_rows)

etfs = {}
for r in selected_rows:
    try:
        etf_names= re.findall('^(.*) \(NYSE', r.text)
        etf_markets = re.findall('\((.*)\|', r.text)
        etf_tickers = re.findall('NYSE Arcal\|(.*)\)', r.text)

        print(etf_markets,etf_names)

        if(len(etf_names) > 0) & (len(etf_tickers) > 0):
            etfs[etf_tikers[0]] = [etf_markets[0], etf_names[0]]
    except AttributeError as error:
        pass

print(etfs)
print('\n')

df= pd.DataFrame(etfs)
print(df)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of American exchange-traded funds - Wikipedia</title>
# ...

# %% [markdown]
# # 데이터프레임 구조 확인과 일부 정보 보기 p 37

# %%
import pandas as pd

df = pd.read_csv("sample\자동차_제원_정보.csv", header=None)

df.columns = ['연비','실린더 수','배기량','마력','중량','엑셀','년식','제조국','차종']

print("행의 갯수 : ", df.shape[0],"개")
print()

df.head()

# %%
df.info()

# %%
df.연비.dtypes

# %%
df.describe(include='all')

# %%
df.count()

# %%
type(df.count())

# %%
unique_values = df['제조국'].value_counts()
unique_values
